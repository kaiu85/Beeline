# %% [markdown]
# <a href="https://colab.research.google.com/github/kaiu85/Beeline/blob/master/MOFA_Tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install additional libraries
# !pip install --quiet leidenalg
# !pip install --quiet muon
#!pip install --quiet scvi-colab
#from scvi_colab import install
#install()
# We need to restart the runtime for all changes to work, this is why 
# we call "exit"
exit()
# This will yield a "Runtime crashed" error due to the
# Python process restarting. Just ignore it and continue with
# executing the next cell.
# Out:
#      |████████████████████████████████| 1.3 MB 13.4 MB/s
#      |████████████████████████████████| 3.2 MB 50.8 MB/s
#      |████████████████████████████████| 287 kB 7.0 MB/s
#      |████████████████████████████████| 2.0 MB 35.7 MB/s
#      |████████████████████████████████| 96 kB 1.4 MB/s
#      |████████████████████████████████| 4.8 MB 62.1 MB/s
#      |████████████████████████████████| 88 kB 3.4 MB/s
#      |████████████████████████████████| 11.2 MB 42.7 MB/s
#      |████████████████████████████████| 965 kB 68.9 MB/s
#      |████████████████████████████████| 1.1 MB 61.5 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done
#   Building wheel for session-info (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done

# %% [markdown]
# # Processing gene expression of 10k PBMCs

# %% [markdown]
# This is the first chapter of the multimodal single-cell gene expression and chromatin accessibility analysis. In this notebook, scRNA-seq data processing is described, largely following [this scanpy notebook](https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html) on processing and clustering PBMCs.

# %% [markdown]
# ## Download data

# %% [markdown]
# Download the data that we will use for this series of notebooks. [The data is available here](https://support.10xgenomics.com/single-cell-multiome-atac-gex/datasets/1.0.0/pbmc_granulocyte_sorted_10k).
#
# For easiness (and as we're using the data purely for educational purposes today), we'll download the data directly to our Colab instances from a private Dropbox. **However**, if you want to use the data for your own research purposes, make sure to download it from the 10X site and read their license carefully!
#
# For the tutorial, we will use the following files:
#
# 1. Filtered feature barcode matrix (HDF5)
# 1. ATAC peak annotations based on proximal genes (TSV)
# 1. ATAC Per fragment information file (TSV.GZ)
# 1. ATAC Per fragment information index (TSV.GZ index)

# %%
import os
# This is the directory where those files are downloaded to (just our base directory)
data_dir = "./data"

# Check if directory exists, if not, create it
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# Download files directly to this Colab instance
# !wget just downloads the file specified by the URL and saves it to
# the destination specified by the -O option.
# !wget https://www.dropbox.com/s/5zsx48hpx4a27fi/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.h5 -O ./data/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.h5
# !wget https://www.dropbox.com/s/db5w0o5eblvwwaj/pbmc_granulocyte_sorted_10k_atac_peak_annotation.tsv -O ./data/pbmc_granulocyte_sorted_10k_atac_peak_annotation.tsv
# !wget https://www.dropbox.com/s/0epid95bs5wa5as/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz -O ./data/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz
# !wget https://www.dropbox.com/s/o4wkf5qzj6rh8mp/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz.tbi -O ./data/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz.tbi
# Out:
# --2022-11-29 20:03:56--  https://www.dropbox.com/s/5zsx48hpx4a27fi/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/5zsx48hpx4a27fi/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.h5 [following]
# --2022-11-29 20:03:57--  https://www.dropbox.com/s/raw/5zsx48hpx4a27fi/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://u

# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/db5w0o5eblvwwaj/pbmc_granulocyte_sorted_10k_atac_peak_annotation.tsv [following]
# --2022-11-29 20:04:11--  https://www.dropbox.com/s/raw/db5w0o5eblvwwaj/pbmc_granulocyte_sorted_10k_atac_peak_annotation.tsv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8b85b2ed61c4d3335d8cc78ea9.dl.dropboxusercontent.com/cd/0/inline/Bxt7AAFuBAbZEUV_RsQv5knT3wLkyl4icg8P8LGdVVxVk1zZxeH4XSRa-o_7bEeDu8rKxpCydPQAZleCvh3SyCIJgX_4ddQkVcNgh0efpKQ8z5xX4XdhZR_g-NjLdfWca8uDDIhfRa-9xCxiaGXSjYoiS821KAiunhHAbmTXVgalpg/file# [following]
# --2022-11-29 20:04:11--  https://uc8b85b2ed61c4d3335d8cc78ea9.dl.dropboxusercontent.com/cd/0/inline/Bxt7AAFuBAbZEUV_RsQv5knT3wLkyl4icg8P8LGdVVxVk1zZxeH4XSRa-o_7bEeDu8rKxpCydPQAZleCvh3SyCIJgX_4ddQkVcNgh0efpKQ8z5xX4XdhZR_g-NjLdfWca8uDDIhfRa-9xCxiaGXSjYoiS821KAiunhHAbmTXVgalpg/file
# Resolving uc8b85b2ed61c4d3335d8cc78ea9.dl.dropboxusercontent.com (uc8b85b2ed61c4d3335d8cc78ea9.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc8b85b2ed61c4d3335d8cc78ea9.dl.dropboxusercontent.com (uc8b85b2ed61c4d3335d8cc78ea9.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5357234 (5.1M) [text/plain]
# Saving to: ‘./data/pbmc_granulocyte_sorted_10k_atac_peak_annotation.tsv’
#
# ./data/pbmc_granulo 100%[===================>]   5.11M  14.7MB/s    in 0.3s
#
# 2022-11-29 20:04:12 (14.7 MB/s) - ‘./data/pbmc_granulocyte_sorted_10k_atac_peak_annotation.tsv’ saved [5357234/5357234]
#
# --2022-11-29 20:04:12--  https://www.dropbox.com/s/0epid95bs5wa5as/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/0epid95bs5wa5as/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz [following]
# --2022-11-29 20:04:13--  https://www.dropbox.com/s/raw/0epid95bs5wa5as/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0721059182685e458e50739f00.dl.dropboxusercontent.com/cd/0/inline/Bxv4Re7PWfjLdlq5Jd8m0CFE0amyMBFg-Vchzwtgziw8Z6t2QUlV0Wph9flercFrAC0Rk1Ekk43TO18f0T__XZ5vyXii9C9VFHPJVqkE8v-RCyh7ssSfBEfatSB3g0WxEeDyZ-9tfHAZZpbY5movdknfXx1XiZkPNObYZsVB5on7Yw/file# [following]
# --2022-11-29 20:04:13--  https://uc0721059182685e458e50739f00.dl.dropboxusercontent.com/cd/0/inline/Bxv4Re7PWfjLdlq5Jd8m0CFE0amyMBFg-Vchzwtgziw8Z6t2QUlV0Wph9flercFrAC0Rk1Ekk43TO18f0T__XZ5vyXii9C9VFHPJVqkE8v-RCyh7ssSfBEfatSB3g0WxEeDyZ-9tfHAZZpbY5movdknfXx1XiZkPNObYZsVB5on7Yw/file
# Resolving uc0721059182685e458e50739f00.dl.dropboxusercontent.com (uc0721059182685e458e50739f00.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc0721059182685e458e50739f00.dl.dropboxusercontent.com (uc0721059182685e458e50739f00.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/
dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BxtunfHPm3ZG7fB2uXRnREllHHP-KJmD5qB_ZQmzAnwt3yOc2QrvlbJ-R-TcMfohZTRxBgEKJfRtiginHeaRFujttmFk-M6LejMadrVDFp2Nx77Pbu8J4KwMuCmRQyvSIHMdgCPGzdoLLk4oT9qDJB8fQPO3zDoFUHdhyCvjvkNw3MyEb9KKG0ibQ-BzdH0MNzF_X5ByJz6zgemURYUdqKg5Siv8uF_JsFL3dRV4rACAIqs0uEzk2ddQ7yUzAsSHiAvTcrjlxtZJdfwCK3LytzqIbrlB5E-hAWzD-a1Aes_pSweg7jyRLvCc2YLiHBfNic18RdzbxCdprwzfK6qf2MyEQBko1muAAHbZDhpcVgnCugyBAO4_HNnGUQlC55-sZNxJqPLJqsgGkK5DVQp6msFYNPe6FNEXUz7QGnWq5_wPWw/file [following]
# --2022-11-29 20:05:49--  https://uc2be3c41efb8b0a20134d5de26a.dl.dropboxusercontent.com/cd/0/inline2/BxtunfHPm3ZG7fB2uXRnREllHHP-KJmD5qB_ZQmzAnwt3yOc2QrvlbJ-R-TcMfohZTRxBgEKJfRtiginHeaRFujttmFk-M6LejMadrVDFp2Nx77Pbu8J4KwMuCmRQyvSIHMdgCPGzdoLLk4oT9qDJB8fQPO3zDoFUHdhyCvjvkNw3MyEb9KKG0ibQ-BzdH0MNzF_X5ByJz6zgemURYUdqKg5Siv8uF_JsFL3dRV4rACAIqs0uEzk2ddQ7yUzAsSHiAvTcrjlxtZJdfwCK3LytzqIbrlB5E-hAWzD-a1Aes_pSweg7jyRLvCc2YLiHBfNic18RdzbxCdprwzfK6qf2MyEQBko1muAAHbZDhpcVgnCugyBAO4_HNnGUQlC55-sZNxJqPLJqsgGkK5DVQp6msFYNPe6FNEXUz7QGnWq5_wPWw/file
# Reusing existing connection to uc2be3c41efb8b0a20134d5de26a.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1027204 (1003K) [application/octet-stream]
# Saving to: ‘./data/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz.tbi’
#
# ./data/pbmc_granulo 100%[===================>]   1003K  --.-KB/s    in 0.1s
#
# 2022-11-29 20:05:49 (7.95 MB/s) - ‘./data/pbmc_granulocyte_sorted_10k_atac_fragments.tsv.gz.tbi’ saved [1027204/1027204]

# %%
# Don't spend too much time on this cell.
# It iterates over all files in data dir and 
# if they start with "pbmc_granulocyte_sorted_10k_" removes that prefix.
prefix = "pbmc_granulocyte_sorted_10k_"
for file in os.listdir(data_dir):
    if file.startswith(prefix):
        new_filename = file[len(prefix):]
        os.rename(os.path.join(data_dir, file), os.path.join(data_dir, new_filename))

# %% [markdown]
# ##Load libraries

# %% [markdown]
# Load the required libraries.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad

# %%
import muon as mu

# %% [markdown]
# We will use an HDF5 file containing gene and peak counts as input. In addition to that, when loading this data, `muon` will look for default files like `atac_peak_annotation.tsv` and `atac_fragments.tsv.gz` in the same folder and will load peak annotation table and remember the path to the fragments file if they exist.

# %%
mdata = mu.read_10x_h5(os.path.join(data_dir, "filtered_feature_bc_matrix.h5"))
mdata.var_names_make_unique()
mdata
# Out:
# /usr/local/lib/python3.7/dist-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# Added `interval` annotation for features from ./data/filtered_feature_bc_matrix.h5
# /usr/local/lib/python3.7/dist-packages/mudata/_core/mudata.py:447: UserWarning: var_names are not unique. To make them unique, call `.var_names_make_unique`.
#   f"{attr}_names are not unique. To make them unique, call `.{attr}_names_make_unique`."
# Added peak annotation from ./data/atac_peak_annotation.tsv to .uns['atac']['peak_annotation']
# Added gene names to peak annotation in .uns['atac']['peak_annotation']
# Located fragments file: ./data/atac_fragments.tsv.gz
# pysam is not available. It is required to work with the fragments file.                 Install pysam from PyPI (`pip install pysam`)                 or from GitHub (`pip install git+https://github.com/pysam-developers/pysam`)
# MuData object with n_obs × n_vars = 11909 × 144978
#   var:	'gene_ids', 'feature_types', 'genome', 'interval'
#   2 modalities
#     rna:	11909 x 36601
#       var:	'gene_ids', 'feature_types', 'genome', 'interval'
#     atac:	11909 x 108377
#       var:	'gene_ids', 'feature_types', 'genome', 'interval'
#       uns:	'atac'

# %% [markdown]
# Muon uses multimodal data (MuData) objects as containers for multimodal data.
#
# `mdata` here is a MuData object that has been created directly from an AnnData object with multiple features types.

# %% [markdown]
# ## RNA

# %% [markdown]
# In this notebook, we will only work with the Gene Expression modality.
#
# We can refer to an individual AnnData inside the MuData by defining a respective variable. All the operations will be performed on the respective AnnData object inside the MuData as you would expect.
#
# > Please note that when AnnData is copied (e.g. `rna = rna.copy()`), there is no way for `mdata` to have a reference to this new object. It should be assigned back to a respective modality then (`mdata.mod['rna'] = rna`).

# %%
rna = mdata.mod['rna']
rna
# Out:
# AnnData object with n_obs × n_vars = 11909 × 36601
#     var: 'gene_ids', 'feature_types', 'genome', 'interval'

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### QC

# %% [markdown]
# Perform some quality control. For now, we will filter out cells that do not pass QC.

# %%
rna.var['mt'] = rna.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(rna, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(rna, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(rna, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(rna, x='total_counts', y='n_genes_by_counts')

# %% [markdown]
# Filter genes which expression is not detected:

# %%
mu.pp.filter_var(rna, 'n_cells_by_counts', lambda x: x >= 3)
# This is analogous to
#   sc.pp.filter_genes(rna, min_cells=3)
# but does in-place filtering and avoids copying the object

# %% [markdown]
# Filter cells:

# %%
mu.pp.filter_obs(rna, 'n_genes_by_counts', lambda x: (x >= 200) & (x < 5000))
# This is analogous to 
#   sc.pp.filter_cells(rna, min_genes=200)
#   rna = rna[rna.obs.n_genes_by_counts < 5000, :]
# but does in-place filtering avoiding copying the object

mu.pp.filter_obs(rna, 'total_counts', lambda x: x < 15000)
mu.pp.filter_obs(rna, 'pct_counts_mt', lambda x: x < 20)

# %% [markdown]
# Let's see how the data looks after filtering:

# %%
sc.pl.violin(rna, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(rna, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(rna, x='total_counts', y='n_genes_by_counts')

# %% [markdown]
# #### Normalisation

# %% [markdown]
# We'll normalise the data so that we get log-normalised counts to work with.

# %%
sc.pp.normalize_total(rna, target_sum=1e4)

# %%
sc.pp.log1p(rna)

# %% [markdown]
# #### Feature selection

# %% [markdown]
# We will label highly variable genes that we'll use for downstream analysis.

# %%
sc.pp.highly_variable_genes(rna, min_mean=0.02, max_mean=4, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(rna)

# %%
np.sum(rna.var.highly_variable)
# Out:
# 3026

# %% [markdown]
# #### Scaling

# %% [markdown]
# We'll save log-normalised counts in a `.raw` slot:

# %%
rna.raw = rna

# %% [markdown]
# ... and scale the log-normalised counts to zero mean and unit variance:

# %%
sc.pp.scale(rna, max_value=10)

# %% [markdown]
# ### Analysis

# %% [markdown]
# Having filtered low-quality cells, normalised the counts matrix, and performed feature selection, we can already use this data for multimodal integration.
#
# However it is usually a good idea to study individual modalities as well.
# Below we run PCA on the scaled matrix, compute cell neighbourhood graph, and perform clustering to define cell types.

# %% [markdown]
# #### PCA and neighbourhood graph

# %%
sc.tl.pca(rna, svd_solver='arpack')

# %% [markdown]
# To visualise the result, we will use some markers for (large-scale) cell populations we expect to see such as T cells and NK cells (CD2), B cells (CD79A), and KLF4 (monocytes).

# %%
sc.pl.pca(rna, color=['CD2', 'CD79A', 'KLF4', 'IRF8'])

# %% [markdown]
# The first principal component (PC1) is separating myeloid (monocytes) and lymphoid (T, B, NK) cells while B cells-related features seem to drive the second one. Also we see plasmocytoid dendritic cells (marked by IRF8) being close to B cells along the PC2.

# %%
sc.pl.pca_variance_ratio(rna, log=True)

# %% [markdown]
# Now we can compute a neighbourhood graph for cells:

# %%
sc.pp.neighbors(rna, n_neighbors=10, n_pcs=20)

# %% [markdown]
# #### Non-linear dimensionality reduction and clustering

# %% [markdown]
# With the neighbourhood graph computed, we can now perform clustering. We will use `leiden` clustering as an example.

# %%
sc.tl.leiden(rna, resolution=.5)

# %% [markdown]
# To visualise the results, we'll first generate a 2D latent space with cells that we can colour according to their cluster assignment.

# %%
sc.tl.umap(rna, spread=1., min_dist=.5, random_state=11)

# %%
sc.pl.umap(rna, color="leiden", legend_loc="on data")

# %% [markdown]
# #### Marker genes and celltypes

# %%
sc.tl.rank_genes_groups(rna, 'leiden', method='t-test')

# %%
result = rna.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.set_option('display.max_columns', 50)
pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'pvals']}).head(10)
# Out:
#         0_n            0_p     1_n            1_p      2_n  2_p     3_n  \
# 0    INPP4B   0.000000e+00    LEF1   0.000000e+00   SLC8A1  0.0    LEF1
# 1      IL32   0.000000e+00  BCL11B   0.000000e+00   PLXDC2  0.0   BACH2
# 2       LTB   0.000000e+00   BACH2   0.000000e+00    NEAT1  0.0   PDE3B
# 3     SYNE2   0.000000e+00   CAMK4   0.000000e+00     AOAH  0.0  THEMIS
# 4      ANK3   0.000000e+00    FHIT   0.000000e+00     DPYD  0.0   NELL2
# 5    CDC14A   0.000000e+00  MALAT1   0.000000e+00     TYMP  0.0  BCL11B
# 6      IL7R   0.000000e+00  RPS27A   0.000000e+00     JAK2  0.0   CAMK4
# 7     ITGB1  7.046117e-311    TCF7  3.422495e-297     FCN1  0.0    CD8B
# 8  ARHGAP15   0.000000e+00   RPS27  3.553412e-309     ZEB2  0.0  OXNAD1
# 9    BCL11B   0.000000e+00  INPP4B  2.308870e-281  DENND1A  0.0     TXK
#
#              3_p       4_n  4_p    5_n            5_p      6_n            6_p  \
# 0   0.000000e+00      VCAN  0.0   CCL5   0.000000e+00    BANK1   0.000000e+00
# 1   0.000000e+00    PLXDC2  0.0   NKG7  6.546803e-264     CD74   0.000000e+00
# 2   0.000000e+00      DPYD  0.0   IL32  5.707436e-285  RALGPS2  2.564287e-316
# 3   0.000000e+00  ARHGAP26  0.0  SYNE2  2.601560e-216     AFF3  1.996289e-313
# 4   0.000000e+00     LRMDA  0.0  PRKCH  6.220691e-203    MS4A1  1.361494e-278
# 5   0.000000e+00     NEAT1  0.0   GZMA  1.998590e-175  OSBPL10  8.911794e-228
# 6   0.000000e+00      FCN1  0.0  SKAP1  4.924050e-185  HLA-DRA  6.100709e-255
# 7  3.667746e-319      ZEB2  0.0    A2M  9.922502e-164    CD79A  1.017956e-225
# 8   0.000000e+00     CSF3R  0.0  HLA-B  8.705329e-170     PAX5  4.409163e-221
# 9  5.115045e-310     RBM47  0.0  SYNE1  7.294187e-161      BLK  1.280629e-195
#
#      7_n            7_p     8_n            8_p     9_n            9_p  \
# 0   GNLY   0.000000e+00  TCF7L2   0.000000e+00   NEAT1  4.718787e-212
# 1   NKG7  1.322684e-278    PSAP   0.000000e+00  PLXDC2  2.628610e-182
# 2  CD247  1.510334e-282     LYN   0.000000e+00    ZEB2  7.727224e-167
# 3   PRF1  5.082462e-224    SAT1   0.000000e+00    LYST  6.523803e-153
# 4  KLRD1  2.917589e-175   MTSS1  2.708539e-294    DPYD  1.410995e-156
# 5   GZMA  3.913498e-171    CST3  1.574385e-291  SLC8A1  1.506365e-141
# 6  SYNE1  4.917205e-165    WARS  1.408956e-284    TYMP  1.073279e-145
# 7  PRKCH  8.991964e-170    CTSS  6.512505e-315     LYN  1.311265e-143
# 8   CTSW  7.274810e-158   COTL1  9.898064e-278    FCN1  3.184471e-135
# 9  MCTP2  1.457122e-153    TYMP  8.108010e-297    AOAH  1.301608e-141
#
#       10_n           10_p      11_n           11_p    12_n          12_p  \
# 0     IGHM  1.717806e-288      CD74  7.028884e-156   RPS29  5.846136e-17
# 1     AFF3  7.544330e-270      CST3  2.806886e-113   RPS12  4.711174e-16
# 2    BANK1  4.769347e-241       LYZ  3.950756e-117   RPS27  5.716096e-15
# 3     CD74  1.556807e-232   HLA-DRA  1.114348e-112   RPS14  1.143721e-13
# 4    FCRL1  6.639307e-170  HLA-DRB1  5.040392e-105   RPL13  2.993995e-13
# 5  RALGPS2  3.628682e-166     HDAC9  1.232631e-103   RPL30  8.805339e-12
# 6  HLA-DRA  5.218864e-177    SAMHD1  1.721821e-107   RPL32  3.015812e-10
# 7    BACH2  8.734891e-164  HLA-DPA1   2.756705e-94   RPS21  3.503708e-10
# 8     PAX5  3.466935e-149  HLA-DPB1   4.788035e-88   RPS26  1.133104e-09
# 9    MS4A1  3.121565e-133  HLA-DQA1   3.627879e-87  RPL27A  5.494638e-09
#
#       13_n          13_p      14_n           14_p     15_n          15_p  \
# 0  SLC4A10  2.634788e-56      TCF4  2.131731e-108    BANK1  3.763633e-47
# 1     NKG7  5.384823e-49      RHEX   9.108036e-85     AFF3  3.540131e-43
# 2  PHACTR2  5.413404e-47      IRF8   2.498881e-83     CD74  4.056818e-40
# 3     RORA  8.477108e-45    FCHSD2   1.102103e-83   MARCH1  3.041279e-38
# 4    SYNE2  8.133900e-43      UGCG   2.849758e-78      LYN  1.349819e-37
# 5     IL7R  1.387635e-38      AFF3   3.814406e-81  HLA-DRA  1.141581e-35
# 6    SKAP1  5.995929e-38      CD74   5.871105e-85   PLXDC2  9.282719e-33
# 7      A2M  7.309596e-37      PLD4   6.527481e-73    MEF2C  5.807981e-31
# 8     CCL5  2.530043e-36    BCL11A   1.199667e-67    MS4A1  2.406745e-30
# 9    KLRB1  6.298874e-36  RABGAP1L   1.325867e-70    PRKCB  5.573922e-30
#
#      16_n          16_p
# 0    CDK6  1.042747e-13
# 1   MAML3  6.821403e-13
# 2    SOX4  1.456599e-12
# 3  NKAIN2  4.956515e-12
# 4   RPLP0  1.187223e-11
# 5   RACK1  2.365494e-11
# 6  RNF220  6.095781e-11
# 7   ZNRF1  9.125703e-11
# 8   RPS3A  1.477149e-10
# 9    EEF2  3.706141e-10

# %%
sc.pl.rank_genes_groups(rna, n_genes=20, sharey=False)

# %% [markdown]
# Exploring the data we notice clusters 9 and 15 seem to be composed of cells bearing markers for different cell lineages so likely to be noise (e.g. doublets). Cluster 12 has higher ribosomal gene expression when compared to other clusters. Cluster 16 seem to consist of proliferating cells.
#
# We will remove cells from these clusters before assigning cell types names to clusters.

# %%
mu.pp.filter_obs(rna, "leiden", lambda x: ~x.isin(["9", "15", "12", "16"]))
# Analogous to
#   rna = rna[~rna.obs.leiden.isin(["9", "15", "12", "16"])]
# but doesn't copy the object

# %%
new_cluster_names = {
    "0": "CD4+ memory T", "1": "CD8+ naïve T", "3": "CD4+ naïve T", 
    "5": "CD8+ activated T", "7": "NK", "13": "MAIT",
    "6": "memory B", "10": "naïve B",
    "4": "CD14 mono", "2": "intermediate mono", "8": "CD16 mono",
    "11": "mDC", "14": "pDC",
}

rna.obs['celltype'] = rna.obs.leiden.astype("str").values
rna.obs.celltype = rna.obs.celltype.astype("category")
rna.obs.celltype = rna.obs.celltype.cat.rename_categories(new_cluster_names)

# %% [markdown]
# We will also re-order categories for the next plots:

# %%
rna.obs.celltype.cat.reorder_categories([
    'CD4+ naïve T', 'CD4+ memory T', 'MAIT',
    'CD8+ naïve T', 'CD8+ activated T', 'NK',
    'naïve B', 'memory B',
    'CD14 mono', 'intermediate mono', 'CD16 mono',
    'mDC', 'pDC'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.

# %% [markdown]
# ... and take colours from a palette:

# %%
import matplotlib
import matplotlib.pyplot as plt

cmap = plt.get_cmap('rainbow')
colors = cmap(np.linspace(0, 1, len(rna.obs.celltype.cat.categories)))

rna.uns["celltype_colors"] = list(map(matplotlib.colors.to_hex, colors))

# %%
sc.pl.umap(rna, color="celltype", legend_loc="on data")

# %% [markdown]
# Finally, we'll visualise some marker genes across cell types.

# %%
marker_genes = ['IL7R', 'TRAC',
                'ITGB1', # CD29
                'SLC4A10',
                'CD8A', 'CD8B', 'CCL5',
                'GNLY', 'NKG7',
                'CD79A', 'MS4A1', 'IGHM', 'IGHD',
                'IL4R', 'TCL1A',
                'KLF4', 'LYZ', 'S100A8', 'ITGAM', # CD11b 
                'CD14', 'FCGR3A', 'MS4A7', 
                'CST3', 'CLEC10A', 'IRF8', 'TCF4']

# %%
sc.pl.dotplot(rna, marker_genes, groupby='celltype');

# %% [markdown]
# ## Saving multimodal data on disk

# %% [markdown]
# We will now write `mdata` object to an `.h5mu` file. It will contain all the changes we've done to the RNA modality (`mdata.mod['rna']`) inside it.

# %%
mdata["atac"].uns = dict(mdata["atac"].uns)
mdata["atac"].uns["atac"] = dict(mdata["atac"].uns["atac"])
mdata.write("data/pbmc10k.h5mu")

# %% [markdown]
# [Next, we'll look into processing the second modality — chromatin accessibility.](2-Chromatin-Accessibility-Processing.ipynb)
